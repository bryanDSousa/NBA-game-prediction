# %%
import pandas as pd
import numpy as np
import calendar

# %%
stats_jugadores = pd.read_csv("./Stats_jugadores_10_04_20.csv")

# %%
stats_jugadores
# Out:
#                       Team  Season                    ID Partido  Local  \
# 233686  Philadelphia 76ers    2019  /boxscores/201810160BOS.html  False
# 233687  Philadelphia 76ers    2019  /boxscores/201810160BOS.html  False
# 233688  Philadelphia 76ers    2019  /boxscores/201810160BOS.html  False
# 233689  Philadelphia 76ers    2019  /boxscores/201810160BOS.html  False
# 233690  Philadelphia 76ers    2019  /boxscores/201810160BOS.html  False
# ...                    ...     ...                           ...    ...
# 280619   Charlotte Hornets    2020  /boxscores/202003110MIA.html   True
# 280620   Charlotte Hornets    2020  /boxscores/202003110MIA.html   True
# 280621   Charlotte Hornets    2020  /boxscores/202003110MIA.html   True
# 280622   Charlotte Hornets    2020  /boxscores/202003110MIA.html   True
# 280623   Charlotte Hornets    2020  /boxscores/202003110MIA.html   True
#
#               Opponent  Team Points  Opponent Points Result              Name  \
# 233686  Boston Celtics         87.0            105.0      W       Simmons,Ben
# 233687  Boston Celtics         87.0            105.0      W       Embiid,Joel
# 233688  Boston Celtics         87.0            105.0      W  Covington,Robert
# 233689  Boston Celtics         87.0            105.0      W    Fultz,Markelle
# 233690  Boston Celtics         87.0            105.0      W       Šarić,Dario
# ...                ...          ...              ...    ...               ...
# 280619      Miami Heat        109.0             98.0      L       Martin,Cody
# 280620      Miami Heat        109.0             98.0      L       Zeller,Cody
# 280621      Miami Heat        109.0             98.0      L      Martin,Caleb
# 280622      Miami Heat        109.0             98.0      L   McDaniels,Jalen
# 280623      Miami Heat        109.0             98.0      L   Biyombo,Bismack
#
#        Minutes Played  ...  Total rebound percentage  Assist percentage  \
# 233686          42:45  ...                      16.5               34.4
# 233687          36:49  ...                      12.8               11.7
# 233688          34:12  ...                       8.3                0.0
# 233689          24:20  ...                       5.8               13.1
# 233690          22:55  ...                      12.3                7.6
# ...               ...  ...                       ...                ...
# 280619          32:24  ...                      13.8                9.1
# 280620          22:29  ...                      27.3               24.3
# 280621          35:00  ...                      11.2               13.1
# 280622          28:56  ...                      11.6                9.4
# 280623          11:11  ...                      10.0                0.0
#
#         Steal percentage  Block percentage  Turnover percentage  \
# 233686               4.3               3.7                 14.0
# 233687               1.3               4.3                 17.7
# 233688               2.7               2.3                 16.7
# 233689               1.9               0.0                 27.6
# 233690               0.0               0.0                 27.3
# ...                  ...               ...                  ...
# 280619               1.7               3.7                 28.6
# 280620               0.0               5.3                  9.3
# 280621               6.2               0.0                  6.1
# 280622               0.0               0.0                 43.6
# 280623               0.0               0.0                  0.0
#
#         Offensive rate  Defensive rate  Box plus minus  Usage percentage  \
# 233686           104.0            90.0             9.8              21.2
# 233687            84.0            98.0             1.1              32.5
# 233688            67.0            99.0            -1.7              14.9
# 233689            52.0           103.0            -8.5              19.0
# 233690            55.0           103.0           -12.1              20.4
# ...                ...             ...             ...               ...
# 280619           108.0           107.0            -2.4               9.8
# 280620           160.0           109.0            12.0              21.7
# 280621           142.0           100.0             9.1              21.4
# 280622            87.0           113.0            -7.2              10.8
# 280623           111.0           114.0            -8.6               8.1
#
#         Complete Date
# 233686     2018-10-16
# 233687     2018-10-16
# 233688     2018-10-16
# 233689     2018-10-16
# 233690     2018-10-16
# ...               ...
# 280619     2020-03-11
# 280620     2020-03-11
# 280621     2020-03-11
# 280622     2020-03-11
# 280623     2020-03-11
#
# [46938 rows x 45 columns]

# %%
stats_jugadores['Season'] = stats_jugadores['Season'].astype('int32')
a = [2019, 2020]
stats_jugadores = stats_jugadores[stats_jugadores.Season.isin(a)]

# %%
stats_jugadores['Year'] = stats_jugadores['Year'].astype('int32').astype('str')
new = stats_jugadores["Date"].str.split(" ", n = 1, expand = True) 
  
# making separate first name column from new data frame 
stats_jugadores["Month"]= new[0] 
  
# making separate last name column from new data frame 
stats_jugadores["Day"]= new[1] 
  
# Dropping old Name columns 
stats_jugadores.drop(columns =["Date"], inplace = True)
# Out:
# C:\Users\34680\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\34680\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\34680\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mes_numero= {}
for k,v in enumerate(calendar.month_abbr):
    mes_numero[v] = k
# Out:
# {'': 0, 'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}

# %%
for indice in stats_jugadores.index:
    if(stats_jugadores.loc[indice,'Month'] in mes_numero.keys()):
        print(indice)
        stats_jugadores.loc[indice,'Month'] = mes_numero[stats_jugadores.loc[indice,'Month']]

# %%
stats_jugadores['Complete Date'] = stats_jugadores['Year'].astype('str') + stats_jugadores['Month'].astype('str')+ stats_jugadores['Day'].astype('str')
# Out:
# C:\Users\34680\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
stats_jugadores['Complete Date'] = pd.to_datetime(stats_jugadores['Complete Date'], format='%Y%m%d', errors='ignore')
# Out:
# C:\Users\34680\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
stats_jugadores.set_index('Complete Date')
# Out:
#                              Team  Season                    ID Partido  \
# Complete Date
# 2018-10-16     Philadelphia 76ers    2019  /boxscores/201810160BOS.html
# 2018-10-16     Philadelphia 76ers    2019  /boxscores/201810160BOS.html
# 2018-10-16     Philadelphia 76ers    2019  /boxscores/201810160BOS.html
# 2018-10-16     Philadelphia 76ers    2019  /boxscores/201810160BOS.html
# 2018-10-16     Philadelphia 76ers    2019  /boxscores/201810160BOS.html
# ...                           ...     ...                           ...
# 2020-03-11      Charlotte Hornets    2020  /boxscores/202003110MIA.html
# 2020-03-11      Charlotte Hornets    2020  /boxscores/202003110MIA.html
# 2020-03-11      Charlotte Hornets    2020  /boxscores/202003110MIA.html
# 2020-03-11      Charlotte Hornets    2020  /boxscores/202003110MIA.html
# 2020-03-11      Charlotte Hornets    2020  /boxscores/202003110MIA.html
#
#                Local        Opponent  Team Points  Opponent Points Result  \
# Complete Date
# 2018-10-16     False  Boston Celtics         87.0            105.0      W
# 2018-10-16     False  Boston Celtics         87.0            105.0      W
# 2018-10-16     False  Boston Celtics         87.0            105.0      W
# 2018-10-16     False  Boston Celtics         87.0            105.0      W
# 2018-10-16     False  Boston Celtics         87.0            105.0      W
# ...              ...             ...          ...              ...    ...
# 2020-03-11      True      Miami Heat        109.0             98.0      L
# 2020-03-11      True      Miami Heat        109.0             98.0      L
# 2020-03-11      True      Miami Heat        109.0             98.0      L
# 2020-03-11      True      Miami Heat        109.0             98.0      L
# 2020-03-11      True      Miami Heat        109.0             98.0      L
#
#                            Name Minutes Played  ...  \
# Complete Date                                   ...
# 2018-10-16          Simmons,Ben          42:45  ...
# 2018-10-16          Embiid,Joel          36:49  ...
# 2018-10-16     Covington,Robert          34:12  ...
# 2018-10-16       Fultz,Markelle          24:20  ...
# 2018-10-16          Šarić,Dario          22:55  ...
# ...                         ...            ...  ...
# 2020-03-11          Martin,Cody          32:24  ...
# 2020-03-11          Zeller,Cody          22:29  ...
# 2020-03-11         Martin,Caleb          35:00  ...
# 2020-03-11      McDaniels,Jalen          28:56  ...
# 2020-03-11      Biyombo,Bismack          11:11  ...
#
#                Defensive rebound percentage  Total rebound percentage  \
# Complete Date
# 2018-10-16                             25.4                      16.5
# 2018-10-16                             19.7                      12.8
# 2018-10-16                             13.2                       8.3
# 2018-10-16                             11.2                       5.8
# 2018-10-16                             23.7                      12.3
# ...                                     ...                       ...
# 2020-03-11                             20.2                      13.8
# 2020-03-11                             24.3                      27.3
# 2020-03-11                             18.7                      11.2
# 2020-03-11                             22.6                      11.6
# 2020-03-11                             19.5                      10.0
#
#                Assist percentage  Steal percentage  Block percentage  \
# Complete Date
# 2018-10-16                  34.4               4.3               3.7
# 2018-10-16                  11.7               1.3               4.3
# 2018-10-16                   0.0               2.7               2.3
# 2018-10-16                  13.1               1.9               0.0
# 2018-10-16                   7.6               0.0               0.0
# ...                          ...               ...               ...
# 2020-03-11                   9.1               1.7               3.7
# 2020-03-11                  24.3               0.0               5.3
# 2020-03-11                  13.1               6.2               0.0
# 2020-03-11                   9.4               0.0               0.0
# 2020-03-11                   0.0               0.0               0.0
#
#                Turnover percentage  Offensive rate  Defensive rate  \
# Complete Date
# 2018-10-16                    14.0           104.0            90.0
# 2018-10-16                    17.7            84.0            98.0
# 2018-10-16                    16.7            67.0            99.0
# 2018-10-16                    27.6            52.0           103.0
# 2018-10-16                    27.3            55.0           103.0
# ...                            ...             ...             ...
# 2020-03-11                    28.6           108.0           107.0
# 2020-03-11                     9.3           160.0           109.0
# 2020-03-11                     6.1           142.0           100.0
# 2020-03-11                    43.6            87.0           113.0
# 2020-03-11                     0.0           111.0           114.0
#
#                Box plus minus  Usage percentage
# Complete Date
# 2018-10-16                9.8              21.2
# 2018-10-16                1.1              32.5
# 2018-10-16               -1.7              14.9
# 2018-10-16               -8.5              19.0
# 2018-10-16              -12.1              20.4
# ...                       ...               ...
# 2020-03-11               -2.4               9.8
# 2020-03-11               12.0              21.7
# 2020-03-11                9.1              21.4
# 2020-03-11               -7.2              10.8
# 2020-03-11               -8.6               8.1
#
# [46938 rows x 44 columns]

# %%
stats_jugadores.drop(columns =["Year", "Day", "Month"], inplace = True)
