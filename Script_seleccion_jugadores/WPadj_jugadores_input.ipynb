# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
from scipy import stats
warnings.filterwarnings(action='ignore')
# %matplotlib inline
# %pylab
# %config InlineBackend.figure_format = 'retina'

temporada = 2017
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### Pasos para el cálculo del "Wins Produced"
#
# Para el cálculo de esta medida de valoración de los jugadores, vamos a partir de dos csv, uno con datos a nivel de encuentro, y otro con datos a nivel de jugador. Ambos contienen la información del boxscore de cada encuentro, pero a distintos niveles de agrupación.
#
# Con este primer csv obtendremos la influencia de cada métrica del boxscore sobre el resultado del partido (W/L) a través de un modelo de regresión.
#
# Posteriormente, utilizaremos esa influencia que hemos obtenido, para calcular la medida de valoración "Wins Produced" a nivel de jugador en cada encuentro. Para este cálculo utilizaremos el segundo csv, que contiene los datos a nivel de jugador.
#
# Una vez obtenido el "Wins Produced", lo utilizaremos para generar dos nuevas variables que incluiremos en nuestro modelo de predicción del resultado de los partidos.
#
# Una de ellas, será una variable de calidad de los jugadores que participan en el encuentro, basada en una media de esta variable en lo que va de temporada para dichos jugadores.
#
# La otra variable será una dummy que indica si el jugador que más aporta al equipo participa en el encuentro o no.

# %% [markdown]
# ### Creamos el modelo para el cálculo del Wins Produced

# %%
# Importamos los datos con información de los partidos desde la visión de local

partidos = pd.read_csv('input.csv')
partidos = partidos.drop_duplicates()
partidos = partidos.dropna()

# Modificamos el formato de algunas variables 

partidos = partidos.drop(columns=['Date'])
partidos['Date']=partidos['ID Partido'].str.extract(pat='(2\w{7})')

partidos['Year'] = partidos['Year'].astype(int)
partidos['Season'] = partidos['Season'].astype(int)
partidos['Points'] = partidos['Points'].astype(int)
partidos['Opponent_Points'] = partidos['Opponent_Points'].astype(int)
partidos['Result_local'] = np.where(partidos['Points'] > partidos['Opponent_Points'], 'W', 'L')
partidos['Result_visitor'] = np.where(partidos['Points'] < partidos['Opponent_Points'], 'W', 'L')


# Seleccionamos las temporadas a incluir en nuestro modelo

temporada = 2017

partidos = partidos.loc[partidos['Season'] > temporada]


#### Creamos el DF para la regresión a nivel de equipo ####

# Dividimos el DF en dos para tenerlo a nivel de equipo, es decir, una fila con el dato del local y otra con el visitante

partidos_visitor = partidos.loc[:, ['Date', 'Year', 'Season', 'ID Partido', 'local_team', 'visitor_team', 'Opponent_Points', 
           'Result_visitor', 'visitor_fg', 'visitor_fga', 'visitor_fg_pct', 'visitor_fg3', 'visitor_fg3a','visitor_fg3_pct',
           'visitor_ft', 'visitor_fta', 'visitor_ft_pct', 'visitor_orb', 'visitor_drb', 'visitor_ast', 'visitor_stl', 
           'visitor_blk', 'visitor_tov', 'visitor_pf', 'visitor_pts', 'visitor_Conf_position', 'visitor_Win', 'visitor_Lose', 
           'visitor_Percentagewl', 'visitor_Dif_leader', 'visitor_Home_win', 'visitor_Home_lose', 'visitor_Away_win', 
           'visitor_Away_lose', 'visitor_Div_win', 'visitor_Div_lose', 'visitor_Cnf_win', 'visitor_Cnf_lose', 'visitor_Icf_win',
           'visitor_Icf_lose', 'local_ft', 'local_fg3', 'local_fg', 'local_tov', 'Sueldo visitante', 'Visitor_Division', 
           'Visitor_Conferencia', 'visitor_trb', 'VISITANTE_Ultimos10Victorias', 'VISITANTE_Ultimos10Derrotas', 
           'VISITANTE_Racha', 'VISITOR_AWS_MEDIO_AGRUPADO']]


# Eliminamos los datos del visitante para el DF del local

partidos = partidos.drop(columns=['Opponent_Points', 'Result_visitor', 'Result', 'visitor_fga', 'visitor_fg_pct',
           'visitor_fg3a','visitor_fg3_pct', 'visitor_fta', 'visitor_ft_pct', 'visitor_orb', 'visitor_drb', 
           'visitor_ast', 'visitor_stl', 'visitor_blk', 'visitor_pf', 'visitor_pts', 'visitor_Conf_position',
           'visitor_Win', 'visitor_Lose', 'visitor_trb', 'visitor_Percentagewl', 'visitor_Dif_leader', 'visitor_Home_win',
           'visitor_Home_lose', 'visitor_Away_win','visitor_Away_lose', 'visitor_Div_win', 'visitor_Div_lose','visitor_Cnf_win',
           'visitor_Cnf_lose', 'visitor_Icf_win', 'visitor_Icf_lose', 'Sueldo visitante', 'Visitor_Division',
           'Visitor_Conferencia', 'VISITANTE_Ultimos10Victorias', 'VISITANTE_Ultimos10Derrotas', 'VISITANTE_Racha',
            'VISITOR_AWS_MEDIO_AGRUPADO'])


# Unificamos los nombres de las variables en ambos DF

partidos = partidos.rename(columns=lambda x: x.replace('local_', ''))
partidos = partidos.rename(columns=lambda x: x.replace('LOCAL_', ''))
partidos = partidos.rename(columns=lambda x: x.replace('Local_', ''))

partidos.rename(columns={'Result_local': 'Result', 'team': 'team_PoV', 'visitor_team': 'Opponent_team', 
                         'visitor_ft': 'FTM_opp', 'visitor_fg': 'FG_opp', 'visitor_fg3': '3FGM_opp', 'visitor_tov': 'TO_opp',
                         'Sueldo local': 'Sueldo'}, inplace=True)


partidos_visitor = partidos_visitor.rename(columns=lambda x: x.replace('visitor_', ''))
partidos_visitor = partidos_visitor.rename(columns=lambda x: x.replace('VISITANTE_', ''))
partidos_visitor = partidos_visitor.rename(columns=lambda x: x.replace('Visitor_', ''))
partidos_visitor = partidos_visitor.rename(columns=lambda x: x.replace('VISITOR_', ''))

partidos_visitor.rename(columns={'Result_visitor': 'Result', 'team': 'team_PoV', 'local_team': 'Opponent_team', 
                                 'Opponent_Points': 'Points', 'local_ft': 'FTM_opp', 'local_fg': 'FG_opp', 
                                 'local_fg3': '3FGM_opp', 'local_tov': 'TO_opp', 'Sueldo visitante':'Sueldo'}, inplace=True)


# Unimos ambos DF verticamente 

partidos_union = pd.concat([partidos, partidos_visitor])


# Creamos las variables necesarias para el cálculo

partidos_union['2FGM'] = partidos_union['fg'] - partidos_union['fg3']
partidos_union['FGMS'] = partidos_union['fga'] - partidos_union['fg']
partidos_union['FTMS'] = partidos_union['fta'] - partidos_union['ft']
partidos_union['2FGM_opp'] = partidos_union['FG_opp'] - partidos_union['3FGM_opp']

partidos_union.rename(columns={'fg3': '3FGM', 'ft': 'FTM', 'orb': 'REBO', 'drb': 'REBD', 'tov': 'TO', 'stl': 'STL', 
                                 'blk': 'BLK'}, inplace=True)


# Generamos la variable dummy Win que tomará valor 1 si el equipo ganó el encuentro

partidos_union['Win'] = np.where(partidos_union['Result'] == 'W', 1, 0)


# Creamos un DF con las variables del modelo

partidos_union_reg = partidos_union.loc[:, ['3FGM', '2FGM', 'FTM', 'FGMS', 'FTMS', 'REBO', 'REBD', 'TO', 'STL', 
                                            'FTM_opp', 'BLK', '3FGM_opp', '2FGM_opp', 'TO_opp', 'Win', 'Percentagewl']]

print(partidos_union_reg.head(5))


#### Generamos el modelo de regresión ####

# Creamos las variables X e Y del modelo

x = partidos_union_reg.loc[:, ['3FGM', '2FGM', 'FTM', 'FGMS', 'FTMS', 'REBO', 'REBD', 'TO', 'STL', 
                                            'FTM_opp', 'BLK',  '3FGM_opp', '2FGM_opp', 'TO_opp']]

y = partidos_union_reg.loc[:, ['Percentagewl']]


from statsmodels.api import OLS

model = OLS(y,x).fit()

print('\n',model.summary())

var = pd.DataFrame(dict(zip(x.columns,model.params)),index=[0]).T
# Out:
#       3FGM  2FGM  FTM  FGMS  FTMS  REBO  REBD  TO  STL  FTM_opp  BLK  \
# 2627     6    11   10    27     3     5    19   8    4        5    1
# 2629     8    14    2    29     3     7    13   5    8        6    5
# 2630     9    15    2    24     2     7    17  11    6        8    1
# 2631     8    14    4    27     3     7    17  11    6        4    6
# 2632     7    23    7    21     3     3    16   4    7        7    3
#
#       3FGM_opp  2FGM_opp  TO_opp  Win  Percentagewl
# 2627         5        13      13    0      0.000000
# 2629         6        16      10    0      0.250000
# 2630         3        20       8    1      0.428571
# 2631         3        25       8    1      0.500000
# 2632         1        21      10    0      0.571429
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           Percentagewl   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     3663.
# Date:                Thu, 07 May 2020   Prob (F-statistic):               0.00
# Time:                        19:31:29   Log-Likelihood:                 1847.3
# No. Observations:                7136   AIC:                            -3667.
# Df Residuals:                    7122   BIC:                            -3570.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 3FGM           0.0185      0.001     13.463      0.000       0.016       0.021
# 2FGM           0.0133      0.001     11.194      0.000       0.011       0.016
# FTM            0.0075      0.001      9.629      0.000       0.006       0.009
# FGMS           0.0084      0.001      7.570      0.000       0.006       0.011
# FTMS           0.0020      0.001      1.413      0.158      -0.001       0.005
# REBO          -0.0077      0.001     -5.286      0.000      -0.011      -0.005
# REBD           0.0018      0.001      1.488      0.137      -0.001       0.004
# TO             0.0048      0.001      3.570      0.000       0.002       0.007
# STL            0.0011      0.002      0.665      0.506      -0.002       0.004
# FTM_opp       -0.0051      0.001     -6.495      0.000      -0.007      -0.004
# BLK            0.0061      0.001      4.471      0.000       0.003       0.009
# 3FGM_opp      -0.0033      0.001     -2.334      0.020      -0.006      -0.001
# 2FGM_opp      -0.0031      0.001     -2.548      0.011      -0.005      -0.001
# TO_opp        -0.0017      0.002     -0.984      0.325      -0.005       0.002
# ==============================================================================
# Omnibus:                       87.760   Durbin-Watson:                   1.268
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.887
# Skew:                          -0.227   Prob(JB):                     3.36e-22
# Kurtosis:                       3.356   Cond. No.                         64.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(partidos_union_reg.corr(), annot=True, fmt='.2f')

# %%
partidos_union_reg.hist(figsize = (12, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2CBC4358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B81FAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B62A080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B655630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B682BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B6BB198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B6E4748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B711D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B711D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B772898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B7A0E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025D2B7D6438>]],
#       dtype=object)

# %% [markdown]
# ### Calculamos el Wins Produced con las ponderaciones obtenidas con el modelo de regresión

# %% [markdown]
# ### Calculamos el WP a nivel de jugador en cada encuentro

# %%
# Importamos el csv con la información de los partidos a nivel de jugador

jugadores = pd.read_csv('Stats_jugadores_27_04_20.csv')
jugadores = jugadores.dropna()

# Modificamos el formato de algunas variables

jugadores['Year'] = jugadores['Year'].astype(int)
jugadores['Season'] = jugadores['Season'].astype(int)

jugadores['Team Points'] = jugadores['Team Points'].astype(int)
jugadores['Opponent Points'] = jugadores['Opponent Points'].astype(int)
jugadores['Result'] = np.where(jugadores['Team Points'] > jugadores['Opponent Points'], 'W', 'L')

jugadores = jugadores.drop(columns=['Date'])
jugadores['Date']=jugadores['ID Partido'].str.extract(pat='(2\w{7})')


# Seleccionamos las temporadas a incluir en nuestro modelo

jugadores_WP = jugadores.loc[jugadores['Season'] > temporada]


# Creamos las variables necesarias para el cálculo

jugadores_WP['2FGM'] = jugadores_WP['Tiros anotados'] - jugadores_WP['Tiros de tres anotados']
jugadores_WP['FGMS'] = jugadores_WP['Tiros intentados'] - jugadores_WP['Tiros anotados']
jugadores_WP['FTMS'] = jugadores_WP['Tiros libres intentados'] - jugadores_WP['Tiros libres anotados']


# Renombramos las variables que vamos a usar para nuestro calculo del AWS

jugadores_WP.rename(columns={'Tiros de tres anotados': '3FGM', 'Tiros libres anotados': 'FTM', 'Rebotes ofensivos': 'REBO',
                                 'Rebotes defensivo': 'REBD', 'Robos': 'STL', 'Tapones': 'BLK', 'Perdidas': 'TO'}, inplace=True)


# Generamos la variable de faltas del total del equipo para obtener el porcentaje de faltas de cada jugador sobre ese total

jugadores_WP_Faltas = jugadores_WP.groupby(['ID Partido', 'Team'], as_index=False).agg({'Faltas':'sum',
                                                                                        'TO':'sum',
                                                                                        'REBD':'sum',
                                                                                        'REBO':'sum',
                                                                                        'BLK':'sum'})
                                                                                       

jugadores_WP_df_jugador = pd.merge(jugadores_WP, jugadores_WP_Faltas, how='left', on=['ID Partido', 'Team'])

jugadores_WP_df_jugador.rename(columns={'Faltas_x': 'Faltas jugador', 'Faltas_y': 'Faltas equipo', 'TO_x': 'TO', 'TO_y': 'TOTM',
                                        'REBD_x': 'REBD', 'REBD_y': 'REBDTM', 'REBO_x': 'REBO', 'REBO_y': 'REBOTM',
                                        'BLK_x': 'BLK', 'BLK_y': 'BLKTM'}, inplace=True)

jugadores_WP_df_jugador['Pct faltas jugador'] = jugadores_WP_df_jugador['Faltas jugador'] / jugadores_WP_df_jugador['Faltas equipo']


# Generamos las variables *_opp con los datos realizados del total del equipo oponente

jugadores_WP_df_opp = jugadores_WP_df_jugador.groupby(['ID Partido', 'Local'], as_index=False).agg({'FTM':'sum',
                                                                                                    '3FGM':'sum',
                                                                                                    '2FGM':'sum',
                                                                                                    'TO':'sum'})

jugadores_WP_df_opp['Local'] = np.where(jugadores_WP_df_opp['Local'] == True, 'False', 'True')

jugadores_WP_df_opp.rename(columns={'FTM': 'FTM_opp_team', '3FGM': '3FGM_opp', '2FGM': '2FGM_opp', 'TO':'TO_opp'}, inplace=True)

jugadores_WP_df_jugador['Local'] = jugadores_WP_df_jugador['Local'].astype(str)

jugadores_WP_df_jugador = pd.merge(jugadores_WP_df_jugador, jugadores_WP_df_opp, how='left', on=['ID Partido', 'Local'])


# Obtenemos el DF final para el cálculo del WP

jugadores_WP_df_jugador['FTM_opp'] = jugadores_WP_df_jugador['Pct faltas jugador'] * jugadores_WP_df_jugador['FTM_opp_team']

jugadores_WP_df_jugador
# Out:
#                      Team  Season  Year                    ID Partido  Local  \
# 0      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 1      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 2      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 3      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 4      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 5      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 6      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 7      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 8      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 9      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 10     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 11     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 12     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 13     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 14     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 15     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 16     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 17     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 18     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 19     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 20     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 21     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 22     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 23     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 24     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 25     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 26     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 27     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 28     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 29     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# ...                   ...     ...   ...                           ...    ...
# 73781   Charlotte Hornets    2020  2020  /boxscores/202003050CHO.html   True
# 73782   Charlotte Hornets    2020  2020  /boxscores/202003050CHO.html   True
# 73783   Charlotte Hornets    2020  2020  /boxscores/202003050CHO.html   True
# 73784   Charlotte Hornets    2020  2020  /boxscores/202003050CHO.html   True
# 73785   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73786   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73787   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73788   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73789   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73790   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73791   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73792   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73793   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73794   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73795   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73796   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73797   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73798   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73799   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73800   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73801   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73802   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73803   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73804   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73805   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73806   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73807   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73808   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73809   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73810   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
#
#                  Opponent  Team Points  Opponent Points Result  \
# 0      Washington Wizards          115              120      L
# 1      Washington Wizards          115              120      L
# 2      Washington Wizards          115              120      L
# 3      Washington Wizards          115              120      L
# 4      Washington Wizards          115              120      L
# 5      Washington Wizards          115              120      L
# 6      Washington Wizards          115              120      L
# 7      Washington Wizards          115              120      L
# 8      Washington Wizards          115              120      L
# 9      Washington Wizards          115              120      L
# 10         Boston Celtics           92              102      L
# 11         Boston Celtics           92              102      L
# 12         Boston Celtics           92              102      L
# 13         Boston Celtics           92              102      L
# 14         Boston Celtics           92              102      L
# 15         Boston Celtics           92              102      L
# 16         Boston Celtics           92              102      L
# 17         Boston Celtics           92              102      L
# 18         Boston Celtics           92              102      L
# 19         Boston Celtics           92              102      L
# 20        Toronto Raptors           94              128      L
# 21        Toronto Raptors           94              128      L
# 22        Toronto Raptors           94              128      L
# 23        Toronto Raptors           94              128      L
# 24        Toronto Raptors           94              128      L
# 25        Toronto Raptors           94              128      L
# 26        Toronto Raptors           94              128      L
# 27        Toronto Raptors           94              128      L
# 28        Toronto Raptors           94              128      L
# 29        Toronto Raptors           94              128      L
# ...                   ...          ...              ...    ...
# 73781      Denver Nuggets          112              114      L
# 73782      Denver Nuggets          112              114      L
# 73783      Denver Nuggets          112              114      L
# 73784      Denver Nuggets          112              114      L
# 73785     Houston Rockets          108               99      W
# 73786     Houston Rockets          108               99      W
# 73787     Houston Rockets          108               99      W
# 73788     Houston Rockets          108               99      W
# 73789     Houston Rockets          108               99      W
# 73790     Houston Rockets          108               99      W
# 73791     Houston Rockets          108               99      W
# 73792     Houston Rockets          108               99      W
# 73793     Houston Rockets          108               99      W
# 73794       Atlanta Hawks          138              143      L
# 73795       Atlanta Hawks          138              143      L
# 73796       Atlanta Hawks          138              143      L
# 73797       Atlanta Hawks          138              143      L
# 73798       Atlanta Hawks          138              143      L
# 73799       Atlanta Hawks          138              143      L
# 73800       Atlanta Hawks          138              143      L
# 73801       Atlanta Hawks          138              143      L
# 73802       Atlanta Hawks          138              143      L
# 73803          Miami Heat          109               98      W
# 73804          Miami Heat          109               98      W
# 73805          Miami Heat          109               98      W
# 73806          Miami Heat          109               98      W
# 73807          Miami Heat          109               98      W
# 73808          Miami Heat          109               98      W
# 73809          Miami Heat          109               98      W
# 73810          Miami Heat          109               98      W
#
#                           Name  ...  TOTM  REBDTM  REBOTM  BLKTM  \
# 0                  Simmons,Ben  ...  17.0    37.0    11.0    6.0
# 1                  Redick,J.J.  ...  17.0    37.0    11.0    6.0
# 2             Covington,Robert  ...  17.0    37.0    11.0    6.0
# 3               Bayless,Jerryd  ...  17.0    37.0    11.0    6.0
# 4                  Embiid,Joel  ...  17.0    37.0    11.0    6.0
# 5                  Šarić,Dario  ...  17.0    37.0    11.0    6.0
# 6      Luwawu-Cabarrot,Timothé  ...  17.0    37.0    11.0    6.0
# 7               Fultz,Markelle  ...  17.0    37.0    11.0    6.0
# 8                 Johnson,Amir  ...  17.0    37.0    11.0    6.0
# 9               McConnell,T.J.  ...  17.0    37.0    11.0    6.0
# 10                 Simmons,Ben  ...  16.0    33.0    14.0    4.0
# 11                 Redick,J.J.  ...  16.0    33.0    14.0    4.0
# 12              Bayless,Jerryd  ...  16.0    33.0    14.0    4.0
# 13                 Embiid,Joel  ...  16.0    33.0    14.0    4.0
# 14            Covington,Robert  ...  16.0    33.0    14.0    4.0
# 15                 Šarić,Dario  ...  16.0    33.0    14.0    4.0
# 16              Fultz,Markelle  ...  16.0    33.0    14.0    4.0
# 17     Luwawu-Cabarrot,Timothé  ...  16.0    33.0    14.0    4.0
# 18              McConnell,T.J.  ...  16.0    33.0    14.0    4.0
# 19                Johnson,Amir  ...  16.0    33.0    14.0    4.0
# 20                 Simmons,Ben  ...  20.0    33.0     8.0    4.0
# 21              Bayless,Jerryd  ...  20.0    33.0     8.0    4.0
# 22                 Redick,J.J.  ...  20.0    33.0     8.0    4.0
# 23            Covington,Robert  ...  20.0    33.0     8.0    4.0
# 24                Johnson,Amir  ...  20.0    33.0     8.0    4.0
# 25              Fultz,Markelle  ...  20.0    33.0     8.0    4.0
# 26                 Šarić,Dario  ...  20.0    33.0     8.0    4.0
# 27               Okafor,Jahlil  ...  20.0    33.0     8.0    4.0
# 28              McConnell,T.J.  ...  20.0    33.0     8.0    4.0
# 29             Anderson,Justin  ...  20.0    33.0     8.0    4.0
# ...                        ...  ...   ...     ...     ...    ...
# 73781              Martin,Cody  ...  13.0    25.0     9.0    2.0
# 73782        Hernangómez,Willy  ...  13.0    25.0     9.0    2.0
# 73783          McDaniels,Jalen  ...  13.0    25.0     9.0    2.0
# 73784             Martin,Caleb  ...  13.0    25.0     9.0    2.0
# 73785             Rozier,Terry  ...  17.0    24.0     6.0    1.0
# 73786          Washington,P.J.  ...  17.0    24.0     6.0    1.0
# 73787          Graham,Devonte'  ...  17.0    24.0     6.0    1.0
# 73788              Zeller,Cody  ...  17.0    24.0     6.0    1.0
# 73789            Bridges,Miles  ...  17.0    24.0     6.0    1.0
# 73790              Martin,Cody  ...  17.0    24.0     6.0    1.0
# 73791             Martin,Caleb  ...  17.0    24.0     6.0    1.0
# 73792        Hernangómez,Willy  ...  17.0    24.0     6.0    1.0
# 73793          McDaniels,Jalen  ...  17.0    24.0     6.0    1.0
# 73794          Graham,Devonte'  ...   3.0    27.0     8.0    6.0
# 73795             Rozier,Terry  ...   3.0    27.0     8.0    6.0
# 73796            Bridges,Miles  ...   3.0    27.0     8.0    6.0
# 73797              Zeller,Cody  ...   3.0    27.0     8.0    6.0
# 73798          Washington,P.J.  ...   3.0    27.0     8.0    6.0
# 73799             Martin,Caleb  ...   3.0    27.0     8.0    6.0
# 73800              Martin,Cody  ...   3.0    27.0     8.0    6.0
# 73801          Biyombo,Bismack  ...   3.0    27.0     8.0    6.0
# 73802          McDaniels,Jalen  ...   3.0    27.0     8.0    6.0
# 73803          Graham,Devonte'  ...  14.0    35.0    15.0    4.0
# 73804          Washington,P.J.  ...  14.0    35.0    15.0    4.0
# 73805            Bridges,Miles  ...  14.0    35.0    15.0    4.0
# 73806              Martin,Cody  ...  14.0    35.0    15.0    4.0
# 73807              Zeller,Cody  ...  14.0    35.0    15.0    4.0
# 73808             Martin,Caleb  ...  14.0    35.0    15.0    4.0
# 73809          McDaniels,Jalen  ...  14.0    35.0    15.0    4.0
# 73810          Biyombo,Bismack  ...  14.0    35.0    15.0    4.0
#
#        Pct faltas jugador  FTM_opp_team  3FGM_opp  2FGM_opp  TO_opp   FTM_opp
# 0                0.107143          30.0       6.0      36.0     9.0  3.214286
# 1                0.142857          30.0       6.0      36.0     9.0  4.285714
# 2                0.142857          30.0       6.0      36.0     9.0  4.285714
# 3                0.142857          30.0       6.0      36.0     9.0  4.285714
# 4                0.071429          30.0       6.0      36.0     9.0  2.142857
# 5                0.107143          30.0       6.0      36.0     9.0  3.214286
# 6                0.071429          30.0       6.0      36.0     9.0  2.142857
# 7                0.000000          30.0       6.0      36.0     9.0  0.000000
# 8                0.214286          30.0       6.0      36.0     9.0  6.428571
# 9                0.000000          30.0       6.0      36.0     9.0  0.000000
# 10               0.066667          22.0      10.0      25.0    19.0  1.466667
# 11               0.033333          22.0      10.0      25.0    19.0  0.733333
# 12               0.133333          22.0      10.0      25.0    19.0  2.933333
# 13               0.033333          22.0      10.0      25.0    19.0  0.733333
jugadores_WP_df_jugador['WP'] = var[0]['3FGM'] * jugadores_WP_df_jugador['3FGM'] + var[0]['2FGM'] * jugadores_WP_df_jugador['2FGM'] + \
                + var[0]['FTM'] * jugadores_WP_df_jugador['FTM'] + var[0]['FGMS'] * jugadores_WP_df_jugador['FGMS'] + \
                + var[0]['FTMS'] * jugadores_WP_df_jugador['FTMS'] + var[0]['REBO'] * jugadores_WP_df_jugador['REBO'] + \
                + var[0]['REBD'] * jugadores_WP_df_jugador['REBD'] + var[0]['TO'] * jugadores_WP_df_jugador['TO'] + \
                + var[0]['STL'] * jugadores_WP_df_jugador['STL'] + var[0]['FTM_opp'] * jugadores_WP_df_jugador['FTM_opp'] + \
                + var[0]['BLK'] * jugadores_WP_df_jugador['BLK']

jugadores_WP_df_jugador['WP_team'] = var[0]['3FGM_opp'] * jugadores_WP_df_jugador['3FGM_opp'] + \
            + var[0]['2FGM_opp'] * jugadores_WP_df_jugador['2FGM_opp'] + var[0]['TO_opp'] * jugadores_WP_df_jugador['TO_opp'] + \
            + var[0]['TO'] * jugadores_WP_df_jugador['TOTM'] + var[0]['REBO'] * jugadores_WP_df_jugador['REBOTM'] + \
            + var[0]['REBD'] * jugadores_WP_df_jugador['REBDTM'] + var[0]['BLK'] * jugadores_WP_df_jugador['BLKTM']

jugadores_WP_df_jugador['WP_adj'] = jugadores_WP_df_jugador['WP'] + jugadores_WP_df_jugador['WP_team']

jugadores_WP_df_jugador
# Out:
#                      Team  Season  Year                    ID Partido  Local  \
# 0      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 1      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 2      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 3      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 4      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 5      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 6      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 7      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 8      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 9      Philadelphia 76ers    2018  2017  /boxscores/201710180WAS.html  False
# 10     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 11     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 12     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 13     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 14     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 15     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 16     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 17     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 18     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 19     Philadelphia 76ers    2018  2017  /boxscores/201710200PHI.html   True
# 20     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 21     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 22     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 23     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 24     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 25     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 26     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 27     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 28     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# 29     Philadelphia 76ers    2018  2017  /boxscores/201710210TOR.html  False
# ...                   ...     ...   ...                           ...    ...
# 73781   Charlotte Hornets    2020  2020  /boxscores/202003050CHO.html   True
# 73782   Charlotte Hornets    2020  2020  /boxscores/202003050CHO.html   True
# 73783   Charlotte Hornets    2020  2020  /boxscores/202003050CHO.html   True
# 73784   Charlotte Hornets    2020  2020  /boxscores/202003050CHO.html   True
# 73785   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73786   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73787   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73788   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73789   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73790   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73791   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73792   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73793   Charlotte Hornets    2020  2020  /boxscores/202003070CHO.html   True
# 73794   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73795   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73796   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73797   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73798   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73799   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73800   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73801   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73802   Charlotte Hornets    2020  2020  /boxscores/202003090ATL.html  False
# 73803   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73804   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73805   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73806   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73807   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73808   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73809   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
# 73810   Charlotte Hornets    2020  2020  /boxscores/202003110MIA.html  False
#
#                  Opponent  Team Points  Opponent Points Result  \
# 0      Washington Wizards          115              120      L
# 1      Washington Wizards          115              120      L
# 2      Washington Wizards          115              120      L
# 3      Washington Wizards          115              120      L
# 4      Washington Wizards          115              120      L
# 5      Washington Wizards          115              120      L
# 6      Washington Wizards          115              120      L
# 7      Washington Wizards          115              120      L
# 8      Washington Wizards          115              120      L
# 9      Washington Wizards          115              120      L
# 10         Boston Celtics           92              102      L
# 11         Boston Celtics           92              102      L
# 12         Boston Celtics           92              102      L
# 13         Boston Celtics           92              102      L
# 14         Boston Celtics           92              102      L
# 15         Boston Celtics           92              102      L
# 16         Boston Celtics           92              102      L
# 17         Boston Celtics           92              102      L
# 18         Boston Celtics           92              102      L
# 19         Boston Celtics           92              102      L
# 20        Toronto Raptors           94              128      L
# 21        Toronto Raptors           94              128      L
# 22        Toronto Raptors           94              128      L
# 23        Toronto Raptors           94              128      L
# 24        Toronto Raptors           94              128      L
# 25        Toronto Raptors           94              128      L
# 26        Toronto Raptors           94              128      L
# 27        Toronto Raptors           94              128      L
# 28        Toronto Raptors           94              128      L
# 29        Toronto Raptors           94              128      L
# ...                   ...          ...              ...    ...
# 73781      Denver Nuggets          112              114      L
# 73782      Denver Nuggets          112              114      L
# 73783      Denver Nuggets          112              114      L
# 73784      Denver Nuggets          112              114      L
# 73785     Houston Rockets          108               99      W
# 73786     Houston Rockets          108               99      W
# 73787     Houston Rockets          108               99      W
# 73788     Houston Rockets          108               99      W
# 73789     Houston Rockets          108               99      W
# 73790     Houston Rockets          108               99      W
# 73791     Houston Rockets          108               99      W
# 73792     Houston Rockets          108               99      W
# 73793     Houston Rockets          108               99      W
# 73794       Atlanta Hawks          138              143      L
# 73795       Atlanta Hawks          138              143      L
# 73796       Atlanta Hawks          138              143      L
# 73797       Atlanta Hawks          138              143      L
# 73798       Atlanta Hawks          138              143      L
# 73799       Atlanta Hawks          138              143      L
# 73800       Atlanta Hawks          138              143      L
# 73801       Atlanta Hawks          138              143      L
# 73802       Atlanta Hawks          138              143      L
# 73803          Miami Heat          109               98      W
# 73804          Miami Heat          109               98      W
# 73805          Miami Heat          109               98      W
# 73806          Miami Heat          109               98      W
# 73807          Miami Heat          109               98      W
# 73808          Miami Heat          109               98      W
# 73809          Miami Heat          109               98      W
# 73810          Miami Heat          109               98      W
#
#                           Name  ... BLKTM  Pct faltas jugador  FTM_opp_team  \
# 0                  Simmons,Ben  ...   6.0            0.107143          30.0
# 1                  Redick,J.J.  ...   6.0            0.142857          30.0
# 2             Covington,Robert  ...   6.0            0.142857          30.0
# 3               Bayless,Jerryd  ...   6.0            0.142857          30.0
# 4                  Embiid,Joel  ...   6.0            0.071429          30.0
# 5                  Šarić,Dario  ...   6.0            0.107143          30.0
# 6      Luwawu-Cabarrot,Timothé  ...   6.0            0.071429          30.0
# 7               Fultz,Markelle  ...   6.0            0.000000          30.0
# 8                 Johnson,Amir  ...   6.0            0.214286          30.0
# 9               McConnell,T.J.  ...   6.0            0.000000          30.0
# 10                 Simmons,Ben  ...   4.0            0.066667          22.0
# 11                 Redick,J.J.  ...   4.0            0.033333          22.0
# 12              Bayless,Jerryd  ...   4.0            0.133333          22.0
# 13                 Embiid,Joel  ...   4.0            0.033333          22.0
# 14            Covington,Robert  ...   4.0            0.166667          22.0
# 15                 Šarić,Dario  ...   4.0            0.166667          22.0
# 16              Fultz,Markelle  ...   4.0            0.133333          22.0
# 17     Luwawu-Cabarrot,Timothé  ...   4.0            0.066667          22.0
# 18              McConnell,T.J.  ...   4.0            0.166667          22.0
# 19                Johnson,Amir  ...   4.0            0.033333          22.0
# 20                 Simmons,Ben  ...   4.0            0.000000          31.0
# 21              Bayless,Jerryd  ...   4.0            0.038462          31.0
# 22                 Redick,J.J.  ...   4.0            0.038462          31.0
# 23            Covington,Robert  ...   4.0            0.153846          31.0
# 24                Johnson,Amir  ...   4.0            0.076923          31.0
# 25              Fultz,Markelle  ...   4.0            0.076923          31.0
# 26                 Šarić,Dario  ...   4.0            0.153846          31.0
# 27               Okafor,Jahlil  ...   4.0            0.153846          31.0
# 28              McConnell,T.J.  ...   4.0            0.153846          31.0
# 29             Anderson,Justin  ...   4.0            0.115385          31.0
# ...                        ...  ...   ...                 ...           ...
# 73781              Martin,Cody  ...   2.0            0.130435          18.0
# 73782        Hernangómez,Willy  ...   2.0            0.043478          18.0
# 73783          McDaniels,Jalen  ...   2.0            0.130435          18.0
# 73784             Martin,Caleb  ...   2.0            0.000000          18.0
# 73785             Rozier,Terry  ...   1.0            0.066667          14.0
# 73786          Washington,P.J.  ...   1.0            0.066667          14.0
# 73787          Graham,Devonte'  ...   1.0            0.066667          14.0
# 73788              Zeller,Cody  ...   1.0            0.133333          14.0
# 73789            Bridges,Miles  ...   1.0            0.133333          14.0
# 73790              Martin,Cody  ...   1.0            0.200000          14.0
# 73791             Martin,Caleb  ...   1.0            0.200000          14.0
# 73792        Hernangómez,Willy  ...   1.0            0.000000          14.0
# 73793          McDaniels,Jalen  ...   1.0            0.133333          14.0
# 73794          Graham,Devonte'  ...   6.0            0.090909          16.0
# 73795             Rozier,Terry  ...   6.0            0.045455          16.0
# 73796            Bridges,Miles  ...   6.0            0.045455          16.0
# 73797              Zeller,Cody  ...   6.0            0.045455          16.0
# 73798          Washington,P.J.  ...   6.0            0.181818          16.0
# 73799             Martin,Caleb  ...   6.0            0.272727          16.0
# 73800              Martin,Cody  ...   6.0            0.136364          16.0
# 73801          Biyombo,Bismack  ...   6.0            0.045455          16.0
# 73802          McDaniels,Jalen  ...   6.0            0.136364          16.0
# 73803          Graham,Devonte'  ...   4.0            0.000000           5.0
# 73804          Washington,P.J.  ...   4.0            0.222222           5.0
# 73805            Bridges,Miles  ...   4.0            0.111111           5.0
# 73806              Martin,Cody  ...   4.0            0.222222           5.0
# 73807              Zeller,Cody  ...   4.0            0.111111           5.0
# 73808             Martin,Caleb  ...   4.0            0.000000           5.0
# 73809          McDaniels,Jalen  ...   4.0            0.222222           5.0
# 73810          Biyombo,Bismack  ...   4.0            0.111111           5.0
#
#        3FGM_opp  2FGM_opp  TO_opp   FTM_opp        WP   WP_team    WP_adj
# 0           6.0      36.0     9.0  3.214286  0.171854 -0.046363  0.125492
# 1           6.0      36.0     9.0  4.285714  0.116676 -0.046363  0.070313
# 73793      15.0      20.0    20.0  1.866667  0.038659 -0.059974 -0.021315
# 73794      21.0      32.0    15.0  1.454545  0.324618 -0.154387  0.170231
# 73795      21.0      32.0    15.0  0.727273  0.349916 -0.154387  0.195529
# 73796      21.0      32.0    15.0  0.727273  0.093650 -0.154387 -0.060737
# 73797      21.0      32.0    15.0  0.727273  0.071700 -0.154387 -0.082687
# 73798      21.0      32.0    15.0  2.909091  0.054902 -0.154387 -0.099485
# 73799      21.0      32.0    15.0  4.363636  0.157574 -0.154387  0.003187
# 73800      21.0      32.0    15.0  2.181818  0.103557 -0.154387 -0.050830
# 73801      21.0      32.0    15.0  0.727273  0.088280 -0.154387 -0.066107
# 73802      21.0      32.0    15.0  2.181818  0.094609 -0.154387 -0.059778
# 73803      15.0      24.0    14.0  0.000000  0.281495 -0.108384  0.173112
# 73804      15.0      24.0    14.0  1.111111  0.177106 -0.108384  0.068723
# 73805      15.0      24.0    14.0  0.555556  0.206597 -0.108384  0.098214
# 73806      15.0      24.0    14.0  1.111111  0.063018 -0.108384 -0.045365
# 73807      15.0      24.0    14.0  0.555556  0.091849 -0.108384 -0.016535
# 73808      15.0      24.0    14.0  0.000000  0.207944 -0.108384  0.099561
# 73809      15.0      24.0    14.0  1.111111  0.069573 -0.108384 -0.038810
# 73810      15.0      24.0    14.0  0.555556  0.022433 -0.108384 -0.085950
#
# [73811 rows x 63 columns]

# %% [markdown]
# ### Obtenemos jugador con mayor Wins Produced del equipo en cada temporada

# %%
# Obtenemos el WP por jugador para la temporada

jugadores_WP_temp = jugadores_WP_df_jugador.groupby(['Team','Name', 'Season'], as_index=False)['WP'].agg({'WP_temp':'mean'})


# Obtenemos la estrella del equipo. Es decir, aquel jugador que tiene mayor WP en cada equipo

WP_Star = jugadores_WP_temp.groupby(['Team', 'Season'])['WP_temp'].transform(max) == jugadores_WP_temp['WP_temp']

print('Dataframe de jugador estrella de cada equipo por temporada: ')
jugadores_WP_temp[WP_Star]
# Out:
# Dataframe de jugador estrella de cada equipo por temporada:
#                         Team                     Name  Season   WP_temp
# 50             Atlanta Hawks          Schröder,Dennis    2018  0.217252
# 61             Atlanta Hawks               Young,Trae    2019  0.216546
# 62             Atlanta Hawks               Young,Trae    2020  0.319217
# 84            Boston Celtics             Irving,Kyrie    2018  0.246875
# 85            Boston Celtics             Irving,Kyrie    2019  0.244515
# 106           Boston Celtics             Tatum,Jayson    2020  0.256686
# 148            Brooklyn Nets             Irving,Kyrie    2020  0.279042
# 168            Brooklyn Nets         Russell,D'Angelo    2018  0.182066
# 169            Brooklyn Nets         Russell,D'Angelo    2019  0.239510
# 193        Charlotte Hornets          Graham,Devonte'    2020  0.207905
# 220        Charlotte Hornets             Walker,Kemba    2018  0.239411
# 221        Charlotte Hornets             Walker,Kemba    2019  0.279900
# 256            Chicago Bulls              LaVine,Zach    2018  0.193211
# 257            Chicago Bulls              LaVine,Zach    2019  0.254026
# 258            Chicago Bulls              LaVine,Zach    2020  0.276067
